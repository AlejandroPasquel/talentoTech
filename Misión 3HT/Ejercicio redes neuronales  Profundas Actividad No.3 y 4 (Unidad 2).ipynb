# %%
# Unidad 2 - actividad 3

import keras
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split


#Generar un conjunto de datos de clasificacion sisntetico:

X,y=make_classification(n_samples=100,n_features=5,n_classes=2)


#division del conjunto de datos

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

#Convertimos las etiquetas a codificacion one-hot utilizando to_categorical de keras. Esto convierte las etiquetas de clases en vectores binarios 
#donde la posicion de la clase activa es 1 y todas las demas son 0.

y_train_categorical=keras.utils.to_categorical(y_train)
y_test_categorical=keras.utils.to_categorical(y_test)

# %%
#creamos el modelo 

model=keras.models.Sequential()

# %%
#se a;aden capas al modelo

# #anadir una capa oculta con 10 neuroanas y activacion relu 
model.add(keras.layers.Dense(20,input_shape=(X_train.shape[1],),activation='relu'))  #input_shape=(X_train.shape[1],) el numero de neuronas de capa de entrada siempre se debe escribir en forma de tupla 
#Por ejemplo, si X_train.shape[1] es 10 (es decir, la entrada tiene 10 características), entonces input_shape se define como (10,)
#Esto indica que cada entrada a esta capa tiene 10 características. La tupla (10,) especifica que la entrada es un vector unidimensional con 10 elementos.
# anadir una capa de salida con 2 neuronas (una para cada clase) y activacion softmax:

model.add(keras.layers.Dense(30,activation='relu'))
model.add(keras.layers.Dense(2,activation='softmax'))
# Out:
# c:\Users\jhinn\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# compilar el modelo : 

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

#o se podria cambiare el optimizador a model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

#entrenar el modelo 

model.fit(X_train,y_train_categorical,epochs=100,batch_size=42,validation_data=(X_test,y_test_categorical))
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 194ms/step - accuracy: 0.6218 - loss: 0.6345 - val_accuracy: 0.4500 - val_loss: 0.6822
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5901 - loss: 0.6345 - val_accuracy: 0.5500 - val_loss: 0.6657
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6222 - loss: 0.6115 - val_accuracy: 0.5500 - val_loss: 0.6505
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6222 - loss: 0.5967 - val_accuracy: 0.6000 - val_loss: 0.6358
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5988 - loss: 0.5943 - val_accuracy: 0.7000 - val_loss: 0.6217
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6476 - loss: 0.5809 - val_accuracy: 0.7500 - val_loss: 0.6076
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6968 - loss: 0.5602 - val_accuracy: 0.7500 - val_loss: 0.5942
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7294 - loss: 0.5337 - val_accuracy: 0.8000 - val_loss: 0.5812
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7377 - loss: 0.5400 - val_accuracy: 0.8000 - val_loss: 0.5682
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7698 - loss: 0.5163 - val_accuracy: 0.8000 - val_loss: 0.5556
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8119 - loss: 0.5104 - val_accuracy: 0.8000 - val_loss: 0.5436
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8528 - loss: 0.4962 - val_accuracy: 0.8000 - val_loss: 0.5318
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8937 - loss: 0.4833 - val_accuracy: 0.8500 - val_loss: 0.5201
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8933 - loss: 0.4756 - val_accuracy: 0.8500 - val_loss: 0.5083
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8857 - loss: 0.4648 - val_accuracy: 0.8500 - val_loss: 0.4968
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9421 - loss: 0.4371 - val_accuracy: 0.8500 - val_loss: 0.4854
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9183 - loss: 0.4367 - val_accuracy: 0.8500 - val_loss: 0.4745
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9262 - loss: 0.4213 - val_accuracy: 0.8500 - val_loss: 0.4636
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9183 - loss: 0.4261 - val_accuracy: 0.8500 - val_loss: 0.4531
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9341 - loss: 0.3999 - val_accuracy: 0.8500 - val_loss: 0.4427
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9103 - loss: 0.4092 - val_accuracy: 0.8500 - val_loss: 0.4327
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9504 - loss: 0.3745 - val_accuracy: 0.8500 - val_loss: 0.4232
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9504 - loss: 0.3660 - val_accuracy: 0.8500 - val_loss: 0.4137
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9266 - loss: 0.3663 - val_accuracy: 0.8500 - val_loss: 0.4047
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9345 - loss: 0.3435 - val_accuracy: 0.8500 - val_loss: 0.3959
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9345 - loss: 0.3434 - val_accuracy: 0.8500 - val_loss: 0.3872
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9508 - loss: 0.3224 - val_accuracy: 0.9000 - val_loss: 0.3790
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9349 - loss: 0.3266 - val_accuracy: 0.9000 - val_loss: 0.3711
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9587 - loss: 0.3076 - val_accuracy: 0.9000 - val_loss: 0.3634
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9504 - loss: 0.2996 - val_accuracy: 0.9000 - val_loss: 0.3560
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9425 - loss: 0.2894 - val_accuracy: 0.9000 - val_loss: 0.3489
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9266 - loss: 0.2888 - val_accuracy: 0.9000 - val_loss: 0.3422
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9504 - loss: 0.2650 - val_accuracy: 0.9000 - val_loss: 0.3355
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9504 - loss: 0.2593 - val_accuracy: 0.9000 - val_loss: 0.3291
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9508 - loss: 0.2620 - val_accuracy: 0.9000 - val_loss: 0.3229
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9508 - loss: 0.2487 - val_accuracy: 0.9000 - val_loss: 0.3171
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9508 - loss: 0.2504 - val_accuracy: 0.9000 - val_loss: 0.3115
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9508 - loss: 0.2433 - val_accuracy: 0.9000 - val_loss: 0.3060
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9587 - loss: 0.2153 - val_accuracy: 0.9000 - val_loss: 0.3007
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9587 - loss: 0.2145 - val_accuracy: 0.9000 - val_loss: 0.2957
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9429 - loss: 0.2324 - val_accuracy: 0.9000 - val_loss: 0.2908
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9429 - loss: 0.2284 - val_accuracy: 0.9000 - val_loss: 0.2862
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9508 - loss: 0.2017 - val_accuracy: 0.9000 - val_loss: 0.2819
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9429 - loss: 0.2103 - val_accuracy: 0.9000 - val_loss: 0.2779
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9587 - loss: 0.1903 - val_accuracy: 0.9000 - val_loss: 0.2742
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9508 - loss: 0.1872 - val_accuracy: 0.9000 - val_loss: 0.2706
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9587 - loss: 0.1838 - val_accuracy: 0.9000 - val_loss: 0.2671
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9508 - loss: 0.1930 - val_accuracy: 0.9000 - val_loss: 0.2639
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9429 - loss: 0.2015 - val_accuracy: 0.9000 - val_loss: 0.2606
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9587 - loss: 0.1703 - val_accuracy: 0.9000 - val_loss: 0.2575
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9429 - loss: 0.1823 - val_accuracy: 0.9000 - val_loss: 0.2545
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9429 - loss: 0.1806 - val_accuracy: 0.9000 - val_loss: 0.2515
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9429 - loss: 0.1820 - val_accuracy: 0.9000 - val_loss: 0.2486
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9429 - loss: 0.1774 - val_accuracy: 0.9000 - val_loss: 0.2457
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9508 - loss: 0.1639 - val_accuracy: 0.9000 - val_loss: 0.2430
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9587 - loss: 0.1557 - val_accuracy: 0.9000 - val_loss: 0.2404
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9587 - loss: 0.1459 - val_accuracy: 0.9000 - val_loss: 0.2379
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9587 - loss: 0.1405 - val_accuracy: 0.9000 - val_loss: 0.2353
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9587 - loss: 0.1487 - val_accuracy: 0.9000 - val_loss: 0.2328
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9508 - loss: 0.1615 - val_accuracy: 0.9000 - val_loss: 0.2303
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9587 - loss: 0.1402 - val_accuracy: 0.9000 - val_loss: 0.2279
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9508 - loss: 0.1490 - val_accuracy: 0.9000 - val_loss: 0.2255
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9508 - loss: 0.1530 - val_accuracy: 0.9000 - val_loss: 0.2232
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9508 - loss: 0.1473 - val_accuracy: 0.9000 - val_loss: 0.2209
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9508 - loss: 0.1488 - val_accuracy: 0.9000 - val_loss: 0.2186
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9587 - loss: 0.1280 - val_accuracy: 0.9000 - val_loss: 0.2166
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9429 - loss: 0.1606 - val_accuracy: 0.9000 - val_loss: 0.2145
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9587 - loss: 0.1308 - val_accuracy: 0.9000 - val_loss: 0.2124
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9508 - loss: 0.1503 - val_accuracy: 0.9000 - val_loss: 0.2103
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9508 - loss: 0.1306 - val_accuracy: 0.9000 - val_loss: 0.2084
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9429 - loss: 0.1542 - val_accuracy: 0.9000 - val_loss: 0.2064
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9508 - loss: 0.1395 - val_accuracy: 0.9000 - val_loss: 0.2045
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9349 - loss: 0.1572 - val_accuracy: 0.9000 - val_loss: 0.2026
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9429 - loss: 0.1444 - val_accuracy: 0.9000 - val_loss: 0.2008
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9429 - loss: 0.1397 - val_accuracy: 0.9000 - val_loss: 0.1990
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9667 - loss: 0.1072 - val_accuracy: 0.9000 - val_loss: 0.1974
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9508 - loss: 0.1293 - val_accuracy: 0.9000 - val_loss: 0.1956
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9667 - loss: 0.1069 - val_accuracy: 0.9000 - val_loss: 0.1941
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9667 - loss: 0.1020 - val_accuracy: 0.9000 - val_loss: 0.1924
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9508 - loss: 0.1304 - val_accuracy: 0.9000 - val_loss: 0.1907
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9429 - loss: 0.1399 - val_accuracy: 0.9000 - val_loss: 0.1891
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9508 - loss: 0.1247 - val_accuracy: 0.9000 - val_loss: 0.1875
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9508 - loss: 0.1164 - val_accuracy: 0.9000 - val_loss: 0.1861
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9587 - loss: 0.1034 - val_accuracy: 0.9000 - val_loss: 0.1847
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9508 - loss: 0.1279 - val_accuracy: 0.9500 - val_loss: 0.1832
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9349 - loss: 0.1420 - val_accuracy: 0.9500 - val_loss: 0.1817
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9429 - loss: 0.1244 - val_accuracy: 0.9500 - val_loss: 0.1803
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9591 - loss: 0.1143 - val_accuracy: 0.9500 - val_loss: 0.1789
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9591 - loss: 0.1203 - val_accuracy: 0.9500 - val_loss: 0.1775
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9671 - loss: 0.1054 - val_accuracy: 0.9500 - val_loss: 0.1761
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9591 - loss: 0.1227 - val_accuracy: 0.9500 - val_loss: 0.1746
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9591 - loss: 0.1251 - val_accuracy: 0.9500 - val_loss: 0.1731
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9671 - loss: 0.1080 - val_accuracy: 0.9500 - val_loss: 0.1717
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9671 - loss: 0.1090 - val_accuracy: 0.9500 - val_loss: 0.1702
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9512 - loss: 0.1330 - val_accuracy: 0.9500 - val_loss: 0.1686
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9671 - loss: 0.0945 - val_accuracy: 0.9500 - val_loss: 0.1672
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9671 - loss: 0.1068 - val_accuracy: 0.9500 - val_loss: 0.1657
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9512 - loss: 0.1327 - val_accuracy: 0.9500 - val_loss: 0.1642
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9591 - loss: 0.1063 - val_accuracy: 0.9500 - val_loss: 0.1629
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9591 - loss: 0.1095 - val_accuracy: 0.9500 - val_loss: 0.1615

# %%
#evaluar el modelo :
#Evaluamos el modelo en el conjunto de prueba y obtenemos la pérdida y la precisión.

loss,accuracy=model.evaluate(X_test,y_test_categorical)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9500 - loss: 0.1615

# %%
# Actividad No.4

#Ejercicio práctico implementar una red neurobal para regresión utilizando keras


import keras
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import pandas as pd
import matplotlib.pyplot as plt

# %%
housing=fetch_california_housing()

# %%
X_train_full,X_test,Y_train_full, y_test=train_test_split(housing.data,housing.target)
X_train,X_valid,y_train,y_valid=train_test_split(X_train_full,Y_train_full)

print('X_train:', X_train.shape)
print('X_test:', X_test.shape)
print('X_valid:', X_valid.shape)
print('y_train:', y_train.shape)
print('y_test:', y_test.shape)
print('y_valid:', y_valid.shape)
# Out:
# X_train: (11610, 8)
# X_test: (5160, 8)
# X_valid: (3870, 8)
# y_train: (11610,)
# y_test: (5160,)
# y_valid: (3870,)

# %%
#escalando

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
X_valid=scaler.transform(X_valid)

# %%
#creeando el modelo de red neuronal 
model = keras.models.Sequential([
    keras.layers.Dense(30, activation='relu', input_shape=(X_train.shape[1],)),
    #keras.layers.Dropout(0.5),  # Añade la capa de dropout con una tasa del 50%
    keras.layers.Dense(1)  # Dado que no se especifica una función de activación, la salida será lineal (sin activación)
])
# Out:
# c:\Users\jhinn\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#compilar el modelo 

model.compile(loss='mean_squared_error',optimizer='sgd',metrics=[keras.metrics.RootMeanSquaredError(),'mean_absolute_percentage_error'])

# %%
history=model.fit(X_train,y_train,epochs=100,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4930 - mean_absolute_percentage_error: 44.1918 - root_mean_squared_error: 1.2057 - val_loss: 0.9744 - val_mean_absolute_percentage_error: 33.1601 - val_root_mean_squared_error: 0.9871
# Epoch 2/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - loss: 0.5851 - mean_absolute_percentage_error: 32.0361 - root_mean_squared_error: 0.7633 - val_loss: 0.4420 - val_mean_absolute_percentage_error: 27.0421 - val_root_mean_squared_error: 0.6649
# Epoch 3/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 0.4211 - mean_absolute_percentage_error: 27.5446 - root_mean_squared_error: 0.6487 - val_loss: 0.4080 - val_mean_absolute_percentage_error: 25.8152 - val_root_mean_squared_error: 0.6388
# Epoch 4/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 0.4824 - mean_absolute_percentage_error: 27.6466 - root_mean_squared_error: 0.6940 - val_loss: 0.3982 - val_mean_absolute_percentage_error: 25.7445 - val_root_mean_squared_error: 0.6311
# Epoch 5/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 0.4187 - mean_absolute_percentage_error: 26.6052 - root_mean_squared_error: 0.6470 - val_loss: 0.3902 - val_mean_absolute_percentage_error: 26.0632 - val_root_mean_squared_error: 0.6247
# Epoch 6/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 0.3974 - mean_absolute_percentage_error: 25.6015 - root_mean_squared_error: 0.6303 - val_loss: 0.3807 - val_mean_absolute_percentage_error: 25.3445 - val_root_mean_squared_error: 0.6170
# Epoch 7/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 0.4109 - mean_absolute_percentage_error: 25.6191 - root_mean_squared_error: 0.6409 - val_loss: 0.3792 - val_mean_absolute_percentage_error: 25.4206 - val_root_mean_squared_error: 0.6158
# Epoch 8/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 0.3867 - mean_absolute_percentage_error: 25.0352 - root_mean_squared_error: 0.6216 - val_loss: 0.3760 - val_mean_absolute_percentage_error: 24.9581 - val_root_mean_squared_error: 0.6132
# Epoch 9/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 0.3780 - mean_absolute_percentage_error: 24.6544 - root_mean_squared_error: 0.6146 - val_loss: 0.3731 - val_mean_absolute_percentage_error: 25.5104 - val_root_mean_squared_error: 0.6108
# Epoch 10/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.3714 - mean_absolute_percentage_error: 25.1207 - root_mean_squared_error: 0.6094 - val_loss: 0.3723 - val_mean_absolute_percentage_error: 24.6251 - val_root_mean_squared_error: 0.6101
# Epoch 11/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - loss: 0.3762 - mean_absolute_percentage_error: 25.4555 - root_mean_squared_error: 0.6132 - val_loss: 0.3677 - val_mean_absolute_percentage_error: 23.9854 - val_root_mean_squared_error: 0.6064
# Epoch 12/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.3733 - mean_absolute_percentage_error: 24.4294 - root_mean_squared_error: 0.6109 - val_loss: 0.3672 - val_mean_absolute_percentage_error: 23.8873 - val_root_mean_squared_error: 0.6059
# Epoch 13/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - loss: 0.4171 - mean_absolute_percentage_error: 24.4776 - root_mean_squared_error: 0.6451 - val_loss: 0.3616 - val_mean_absolute_percentage_error: 23.7946 - val_root_mean_squared_error: 0.6013
# Epoch 14/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.3614 - mean_absolute_percentage_error: 24.4838 - root_mean_squared_error: 0.6011 - val_loss: 0.3570 - val_mean_absolute_percentage_error: 24.1688 - val_root_mean_squared_error: 0.5975
# Epoch 15/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.3849 - mean_absolute_percentage_error: 24.6003 - root_mean_squared_error: 0.6197 - val_loss: 0.3646 - val_mean_absolute_percentage_error: 24.1640 - val_root_mean_squared_error: 0.6038
# Epoch 16/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 0.3641 - mean_absolute_percentage_error: 24.0154 - root_mean_squared_error: 0.6031 - val_loss: 0.3557 - val_mean_absolute_percentage_error: 24.5193 - val_root_mean_squared_error: 0.5964
# Epoch 17/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 0.4027 - mean_absolute_percentage_error: 24.4187 - root_mean_squared_error: 0.6327 - val_loss: 0.3631 - val_mean_absolute_percentage_error: 23.5039 - val_root_mean_squared_error: 0.6026
# Epoch 18/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 0.3449 - mean_absolute_percentage_error: 23.5907 - root_mean_squared_error: 0.5871 - val_loss: 0.3556 - val_mean_absolute_percentage_error: 23.5388 - val_root_mean_squared_error: 0.5963
# Epoch 19/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 0.3636 - mean_absolute_percentage_error: 23.8406 - root_mean_squared_error: 0.6029 - val_loss: 0.3491 - val_mean_absolute_percentage_error: 24.0574 - val_root_mean_squared_error: 0.5909
# Epoch 20/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - loss: 0.3476 - mean_absolute_percentage_error: 23.8650 - root_mean_squared_error: 0.5894 - val_loss: 0.3435 - val_mean_absolute_percentage_error: 24.0635 - val_root_mean_squared_error: 0.5861
# Epoch 21/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 0.3501 - mean_absolute_percentage_error: 23.8918 - root_mean_squared_error: 0.5917 - val_loss: 0.3523 - val_mean_absolute_percentage_error: 23.5753 - val_root_mean_squared_error: 0.5935
# Epoch 22/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.3435 - mean_absolute_percentage_error: 23.7212 - root_mean_squared_error: 0.5859 - val_loss: 0.3423 - val_mean_absolute_percentage_error: 23.3942 - val_root_mean_squared_error: 0.5850
# Epoch 23/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.4080 - mean_absolute_percentage_error: 24.3756 - root_mean_squared_error: 0.6378 - val_loss: 0.3492 - val_mean_absolute_percentage_error: 24.7704 - val_root_mean_squared_error: 0.5910
# Epoch 24/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.3421 - mean_absolute_percentage_error: 24.0109 - root_mean_squared_error: 0.5848 - val_loss: 0.3426 - val_mean_absolute_percentage_error: 23.0627 - val_root_mean_squared_error: 0.5853
# Epoch 25/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 0.3550 - mean_absolute_percentage_error: 23.7848 - root_mean_squared_error: 0.5957 - val_loss: 0.3436 - val_mean_absolute_percentage_error: 22.6199 - val_root_mean_squared_error: 0.5861
# Epoch 26/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 0.3405 - mean_absolute_percentage_error: 23.4811 - root_mean_squared_error: 0.5834 - val_loss: 0.3460 - val_mean_absolute_percentage_error: 24.5315 - val_root_mean_squared_error: 0.5882
# Epoch 27/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - loss: 0.3453 - mean_absolute_percentage_error: 23.8824 - root_mean_squared_error: 0.5875 - val_loss: 0.3399 - val_mean_absolute_percentage_error: 23.6495 - val_root_mean_squared_error: 0.5830
# Epoch 28/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - loss: 0.3484 - mean_absolute_percentage_error: 23.9963 - root_mean_squared_error: 0.5900 - val_loss: 0.3352 - val_mean_absolute_percentage_error: 22.6333 - val_root_mean_squared_error: 0.5790
# Epoch 29/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 0.3494 - mean_absolute_percentage_error: 23.2242 - root_mean_squared_error: 0.5909 - val_loss: 0.3360 - val_mean_absolute_percentage_error: 22.9540 - val_root_mean_squared_error: 0.5797
# Epoch 30/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.3224 - mean_absolute_percentage_error: 22.8625 - root_mean_squared_error: 0.5676 - val_loss: 0.3416 - val_mean_absolute_percentage_error: 24.3476 - val_root_mean_squared_error: 0.5844
# Epoch 31/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 0.3246 - mean_absolute_percentage_error: 23.2418 - root_mean_squared_error: 0.5694 - val_loss: 0.3322 - val_mean_absolute_percentage_error: 22.5771 - val_root_mean_squared_error: 0.5764
# Epoch 32/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.3304 - mean_absolute_percentage_error: 22.9853 - root_mean_squared_error: 0.5745 - val_loss: 0.3294 - val_mean_absolute_percentage_error: 22.4127 - val_root_mean_squared_error: 0.5740
# Epoch 33/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - loss: 0.3156 - mean_absolute_percentage_error: 22.6111 - root_mean_squared_error: 0.5616 - val_loss: 0.3314 - val_mean_absolute_percentage_error: 23.1725 - val_root_mean_squared_error: 0.5756
# Epoch 34/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.3400 - mean_absolute_percentage_error: 22.7592 - root_mean_squared_error: 0.5829 - val_loss: 0.3316 - val_mean_absolute_percentage_error: 23.4549 - val_root_mean_squared_error: 0.5758
# Epoch 35/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 0.3312 - mean_absolute_percentage_error: 23.0860 - root_mean_squared_error: 0.5754 - val_loss: 0.3309 - val_mean_absolute_percentage_error: 23.5422 - val_root_mean_squared_error: 0.5752
# Epoch 36/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.3173 - mean_absolute_percentage_error: 23.0380 - root_mean_squared_error: 0.5630 - val_loss: 0.3345 - val_mean_absolute_percentage_error: 22.3983 - val_root_mean_squared_error: 0.5783
# Epoch 37/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 0.3206 - mean_absolute_percentage_error: 22.7482 - root_mean_squared_error: 0.5661 - val_loss: 0.3324 - val_mean_absolute_percentage_error: 23.5833 - val_root_mean_squared_error: 0.5765
# Epoch 38/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.3366 - mean_absolute_percentage_error: 23.1026 - root_mean_squared_error: 0.5801 - val_loss: 0.3269 - val_mean_absolute_percentage_error: 22.2766 - val_root_mean_squared_error: 0.5718
# Epoch 39/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.3225 - mean_absolute_percentage_error: 22.7100 - root_mean_squared_error: 0.5677 - val_loss: 0.3256 - val_mean_absolute_percentage_error: 21.8844 - val_root_mean_squared_error: 0.5706
# Epoch 40/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - loss: 0.3334 - mean_absolute_percentage_error: 22.6343 - root_mean_squared_error: 0.5773 - val_loss: 0.3282 - val_mean_absolute_percentage_error: 21.8709 - val_root_mean_squared_error: 0.5729
# Epoch 41/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.3214 - mean_absolute_percentage_error: 22.3830 - root_mean_squared_error: 0.5667 - val_loss: 0.3253 - val_mean_absolute_percentage_error: 22.5798 - val_root_mean_squared_error: 0.5703
# Epoch 42/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.3267 - mean_absolute_percentage_error: 22.5883 - root_mean_squared_error: 0.5715 - val_loss: 0.3278 - val_mean_absolute_percentage_error: 22.8952 - val_root_mean_squared_error: 0.5726
# Epoch 43/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.3158 - mean_absolute_percentage_error: 22.4355 - root_mean_squared_error: 0.5617 - val_loss: 0.3262 - val_mean_absolute_percentage_error: 22.9784 - val_root_mean_squared_error: 0.5711
# Epoch 44/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 0.3209 - mean_absolute_percentage_error: 22.6118 - root_mean_squared_error: 0.5664 - val_loss: 0.3271 - val_mean_absolute_percentage_error: 22.4038 - val_root_mean_squared_error: 0.5719
# Epoch 45/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.3248 - mean_absolute_percentage_error: 22.5706 - root_mean_squared_error: 0.5699 - val_loss: 0.3262 - val_mean_absolute_percentage_error: 22.6460 - val_root_mean_squared_error: 0.5712
# Epoch 46/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.3197 - mean_absolute_percentage_error: 22.4236 - root_mean_squared_error: 0.5652 - val_loss: 0.3223 - val_mean_absolute_percentage_error: 22.0824 - val_root_mean_squared_error: 0.5677
# Epoch 47/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 0.3253 - mean_absolute_percentage_error: 22.1014 - root_mean_squared_error: 0.5702 - val_loss: 0.3248 - val_mean_absolute_percentage_error: 22.2672 - val_root_mean_squared_error: 0.5700
# Epoch 48/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 0.3309 - mean_absolute_percentage_error: 22.6837 - root_mean_squared_error: 0.5747 - val_loss: 0.3223 - val_mean_absolute_percentage_error: 21.9892 - val_root_mean_squared_error: 0.5677
# Epoch 49/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.3117 - mean_absolute_percentage_error: 22.3117 - root_mean_squared_error: 0.5581 - val_loss: 0.3247 - val_mean_absolute_percentage_error: 23.9289 - val_root_mean_squared_error: 0.5698
# Epoch 50/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.3297 - mean_absolute_percentage_error: 22.6794 - root_mean_squared_error: 0.5741 - val_loss: 0.3221 - val_mean_absolute_percentage_error: 22.7401 - val_root_mean_squared_error: 0.5675
# Epoch 51/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.3130 - mean_absolute_percentage_error: 22.1562 - root_mean_squared_error: 0.5595 - val_loss: 0.3222 - val_mean_absolute_percentage_error: 23.3653 - val_root_mean_squared_error: 0.5676
# Epoch 52/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.3149 - mean_absolute_percentage_error: 22.1980 - root_mean_squared_error: 0.5609 - val_loss: 0.3223 - val_mean_absolute_percentage_error: 22.4611 - val_root_mean_squared_error: 0.5677
# Epoch 53/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.3132 - mean_absolute_percentage_error: 22.0231 - root_mean_squared_error: 0.5595 - val_loss: 0.3204 - val_mean_absolute_percentage_error: 21.9054 - val_root_mean_squared_error: 0.5661
# Epoch 54/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - loss: 0.3202 - mean_absolute_percentage_error: 22.7293 - root_mean_squared_error: 0.5656 - val_loss: 0.3257 - val_mean_absolute_percentage_error: 23.9650 - val_root_mean_squared_error: 0.5707
# Epoch 55/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.3116 - mean_absolute_percentage_error: 22.4637 - root_mean_squared_error: 0.5581 - val_loss: 0.3203 - val_mean_absolute_percentage_error: 22.9030 - val_root_mean_squared_error: 0.5660
# Epoch 56/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.3147 - mean_absolute_percentage_error: 22.3003 - root_mean_squared_error: 0.5607 - val_loss: 0.3247 - val_mean_absolute_percentage_error: 22.0812 - val_root_mean_squared_error: 0.5699
# Epoch 57/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 0.3084 - mean_absolute_percentage_error: 22.2869 - root_mean_squared_error: 0.5552 - val_loss: 0.3280 - val_mean_absolute_percentage_error: 23.7296 - val_root_mean_squared_error: 0.5727
# Epoch 58/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.3176 - mean_absolute_percentage_error: 22.4671 - root_mean_squared_error: 0.5635 - val_loss: 0.3230 - val_mean_absolute_percentage_error: 22.1858 - val_root_mean_squared_error: 0.5684
# Epoch 59/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 0.3192 - mean_absolute_percentage_error: 22.1457 - root_mean_squared_error: 0.5648 - val_loss: 0.3210 - val_mean_absolute_percentage_error: 22.4839 - val_root_mean_squared_error: 0.5666
# Epoch 60/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 0.3081 - mean_absolute_percentage_error: 22.0652 - root_mean_squared_error: 0.5549 - val_loss: 0.3190 - val_mean_absolute_percentage_error: 22.6594 - val_root_mean_squared_error: 0.5648
# Epoch 61/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2976 - mean_absolute_percentage_error: 21.9490 - root_mean_squared_error: 0.5451 - val_loss: 0.3187 - val_mean_absolute_percentage_error: 22.4323 - val_root_mean_squared_error: 0.5645
# Epoch 62/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3041 - mean_absolute_percentage_error: 21.9451 - root_mean_squared_error: 0.5512 - val_loss: 0.3202 - val_mean_absolute_percentage_error: 22.9606 - val_root_mean_squared_error: 0.5659
# Epoch 63/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3090 - mean_absolute_percentage_error: 22.1985 - root_mean_squared_error: 0.5556 - val_loss: 0.3182 - val_mean_absolute_percentage_error: 22.4265 - val_root_mean_squared_error: 0.5641
# Epoch 64/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.3003 - mean_absolute_percentage_error: 21.9122 - root_mean_squared_error: 0.5477 - val_loss: 0.3244 - val_mean_absolute_percentage_error: 22.0415 - val_root_mean_squared_error: 0.5696
# Epoch 65/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.2984 - mean_absolute_percentage_error: 22.2460 - root_mean_squared_error: 0.5462 - val_loss: 0.3192 - val_mean_absolute_percentage_error: 22.7881 - val_root_mean_squared_error: 0.5650
# Epoch 66/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.3132 - mean_absolute_percentage_error: 22.3311 - root_mean_squared_error: 0.5595 - val_loss: 0.3155 - val_mean_absolute_percentage_error: 22.6122 - val_root_mean_squared_error: 0.5617
# Epoch 67/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.3039 - mean_absolute_percentage_error: 21.9913 - root_mean_squared_error: 0.5510 - val_loss: 0.3173 - val_mean_absolute_percentage_error: 22.4118 - val_root_mean_squared_error: 0.5633
# Epoch 68/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 0.3066 - mean_absolute_percentage_error: 22.0374 - root_mean_squared_error: 0.5536 - val_loss: 0.3238 - val_mean_absolute_percentage_error: 23.2248 - val_root_mean_squared_error: 0.5690
# Epoch 69/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - loss: 0.3184 - mean_absolute_percentage_error: 21.7846 - root_mean_squared_error: 0.5638 - val_loss: 0.3187 - val_mean_absolute_percentage_error: 22.1375 - val_root_mean_squared_error: 0.5645
# Epoch 70/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - loss: 0.2965 - mean_absolute_percentage_error: 21.4812 - root_mean_squared_error: 0.5442 - val_loss: 0.3190 - val_mean_absolute_percentage_error: 22.5243 - val_root_mean_squared_error: 0.5648
# Epoch 71/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3182 - mean_absolute_percentage_error: 22.2794 - root_mean_squared_error: 0.5640 - val_loss: 0.3161 - val_mean_absolute_percentage_error: 22.1262 - val_root_mean_squared_error: 0.5622
# Epoch 72/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - loss: 0.3020 - mean_absolute_percentage_error: 21.7356 - root_mean_squared_error: 0.5494 - val_loss: 0.3152 - val_mean_absolute_percentage_error: 22.0658 - val_root_mean_squared_error: 0.5614
# Epoch 73/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - loss: 0.3077 - mean_absolute_percentage_error: 21.9401 - root_mean_squared_error: 0.5545 - val_loss: 0.3170 - val_mean_absolute_percentage_error: 23.0000 - val_root_mean_squared_error: 0.5630
# Epoch 74/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.3035 - mean_absolute_percentage_error: 21.8570 - root_mean_squared_error: 0.5508 - val_loss: 0.3154 - val_mean_absolute_percentage_error: 21.8911 - val_root_mean_squared_error: 0.5616
# Epoch 75/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.3046 - mean_absolute_percentage_error: 21.5854 - root_mean_squared_error: 0.5517 - val_loss: 0.3188 - val_mean_absolute_percentage_error: 21.3277 - val_root_mean_squared_error: 0.5646
# Epoch 76/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - loss: 0.3100 - mean_absolute_percentage_error: 22.0615 - root_mean_squared_error: 0.5567 - val_loss: 0.3160 - val_mean_absolute_percentage_error: 22.9453 - val_root_mean_squared_error: 0.5621
# Epoch 77/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 0.3257 - mean_absolute_percentage_error: 22.1890 - root_mean_squared_error: 0.5706 - val_loss: 0.3176 - val_mean_absolute_percentage_error: 21.8812 - val_root_mean_squared_error: 0.5636
# Epoch 78/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 0.3121 - mean_absolute_percentage_error: 22.6779 - root_mean_squared_error: 0.5585 - val_loss: 0.3157 - val_mean_absolute_percentage_error: 21.7496 - val_root_mean_squared_error: 0.5618
# Epoch 79/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - loss: 0.3046 - mean_absolute_percentage_error: 21.8894 - root_mean_squared_error: 0.5518 - val_loss: 0.3261 - val_mean_absolute_percentage_error: 24.0858 - val_root_mean_squared_error: 0.5710
# Epoch 80/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 0.3280 - mean_absolute_percentage_error: 22.8132 - root_mean_squared_error: 0.5723 - val_loss: 0.3191 - val_mean_absolute_percentage_error: 22.5195 - val_root_mean_squared_error: 0.5649
# Epoch 81/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.3217 - mean_absolute_percentage_error: 22.0244 - root_mean_squared_error: 0.5668 - val_loss: 0.3152 - val_mean_absolute_percentage_error: 22.7135 - val_root_mean_squared_error: 0.5614
# Epoch 82/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 0.2995 - mean_absolute_percentage_error: 21.7924 - root_mean_squared_error: 0.5472 - val_loss: 0.3161 - val_mean_absolute_percentage_error: 22.1030 - val_root_mean_squared_error: 0.5623
# Epoch 83/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - loss: 0.3056 - mean_absolute_percentage_error: 21.9786 - root_mean_squared_error: 0.5526 - val_loss: 0.3206 - val_mean_absolute_percentage_error: 23.1130 - val_root_mean_squared_error: 0.5662
# Epoch 84/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 0.3109 - mean_absolute_percentage_error: 21.8606 - root_mean_squared_error: 0.5575 - val_loss: 0.3154 - val_mean_absolute_percentage_error: 22.1155 - val_root_mean_squared_error: 0.5616
# Epoch 85/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - loss: 0.3170 - mean_absolute_percentage_error: 22.2029 - root_mean_squared_error: 0.5629 - val_loss: 0.3141 - val_mean_absolute_percentage_error: 21.8113 - val_root_mean_squared_error: 0.5605
# Epoch 86/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.2905 - mean_absolute_percentage_error: 21.4669 - root_mean_squared_error: 0.5386 - val_loss: 0.3172 - val_mean_absolute_percentage_error: 22.5732 - val_root_mean_squared_error: 0.5632
# Epoch 87/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 0.3013 - mean_absolute_percentage_error: 21.7886 - root_mean_squared_error: 0.5488 - val_loss: 0.3127 - val_mean_absolute_percentage_error: 21.4891 - val_root_mean_squared_error: 0.5592
# Epoch 88/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - loss: 0.3022 - mean_absolute_percentage_error: 21.9160 - root_mean_squared_error: 0.5495 - val_loss: 0.3183 - val_mean_absolute_percentage_error: 21.4113 - val_root_mean_squared_error: 0.5641
# Epoch 89/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 0.3060 - mean_absolute_percentage_error: 21.6657 - root_mean_squared_error: 0.5530 - val_loss: 0.3120 - val_mean_absolute_percentage_error: 22.3685 - val_root_mean_squared_error: 0.5586
# Epoch 90/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.3052 - mean_absolute_percentage_error: 21.4807 - root_mean_squared_error: 0.5523 - val_loss: 0.3152 - val_mean_absolute_percentage_error: 21.5327 - val_root_mean_squared_error: 0.5614
# Epoch 91/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 0.3110 - mean_absolute_percentage_error: 22.0642 - root_mean_squared_error: 0.5574 - val_loss: 0.3191 - val_mean_absolute_percentage_error: 23.4656 - val_root_mean_squared_error: 0.5649
# Epoch 92/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 0.2965 - mean_absolute_percentage_error: 21.4635 - root_mean_squared_error: 0.5443 - val_loss: 0.3177 - val_mean_absolute_percentage_error: 22.5394 - val_root_mean_squared_error: 0.5637
# Epoch 93/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - loss: 0.2979 - mean_absolute_percentage_error: 21.5014 - root_mean_squared_error: 0.5456 - val_loss: 0.3171 - val_mean_absolute_percentage_error: 21.6415 - val_root_mean_squared_error: 0.5631
# Epoch 94/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.3153 - mean_absolute_percentage_error: 22.0065 - root_mean_squared_error: 0.5613 - val_loss: 0.3138 - val_mean_absolute_percentage_error: 22.5108 - val_root_mean_squared_error: 0.5602
# Epoch 95/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.2970 - mean_absolute_percentage_error: 21.8166 - root_mean_squared_error: 0.5449 - val_loss: 0.3141 - val_mean_absolute_percentage_error: 22.3035 - val_root_mean_squared_error: 0.5605
# Epoch 96/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - loss: 0.3165 - mean_absolute_percentage_error: 21.9880 - root_mean_squared_error: 0.5624 - val_loss: 0.3141 - val_mean_absolute_percentage_error: 22.6505 - val_root_mean_squared_error: 0.5605
# Epoch 97/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - loss: 0.2979 - mean_absolute_percentage_error: 21.8596 - root_mean_squared_error: 0.5457 - val_loss: 0.3176 - val_mean_absolute_percentage_error: 23.3578 - val_root_mean_squared_error: 0.5635
# Epoch 98/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.3020 - mean_absolute_percentage_error: 22.0091 - root_mean_squared_error: 0.5494 - val_loss: 0.3114 - val_mean_absolute_percentage_error: 21.8573 - val_root_mean_squared_error: 0.5580
# Epoch 99/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 0.2969 - mean_absolute_percentage_error: 21.7164 - root_mean_squared_error: 0.5448 - val_loss: 0.3208 - val_mean_absolute_percentage_error: 23.2997 - val_root_mean_squared_error: 0.5664
# Epoch 100/100
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 0.2964 - mean_absolute_percentage_error: 21.9845 - root_mean_squared_error: 0.5443 - val_loss: 0.3157 - val_mean_absolute_percentage_error: 22.3425 - val_root_mean_squared_error: 0.5619

# %%
# Graficar el historial de entrenamiento:
dfHistory = pd.DataFrame(history.history)
dfHistory[['loss', 'val_loss', 'root_mean_squared_error', 'val_root_mean_squared_error']].plot(grid=True)
dfHistory[['mean_absolute_percentage_error', 'val_mean_absolute_percentage_error']].plot(grid=True)

#history es un objeto devuelto por el método fit de un modelo de Keras. Este objeto guarda toda la información sobre el
#  proceso de entrenamiento del modelo, 
# incluyendo los valores de las métricas y las pérdidas para cada época.

#history.history es un diccionario que contiene las listas de valores de las métricas registradas durante el entrenamiento y la validación.
#  Las claves del diccionario son los nombres de las métricas, como 'loss', 'val_loss', 'accuracy', etc.,
#  y los valores son listas que contienen los valores de estas métricas para cada época de entrenamiento.
# Out:
# <Axes: >

# %%
dfHistory
# Out:
#         loss  mean_absolute_percentage_error  root_mean_squared_error  \
# 0   1.266361                       40.000801                 1.125327
# 1   0.533334                       30.925671                 0.730298
# 2   0.434790                       27.667143                 0.659386
# 3   0.450323                       26.983709                 0.671061
# 4   0.407326                       26.098358                 0.638221
# ..       ...                             ...                      ...
# 95  0.303101                       21.813608                 0.550546
# 96  0.303634                       21.793524                 0.551030
# 97  0.304120                       21.899868                 0.551471
# 98  0.302972                       21.796183                 0.550429
# 99  0.302871                       21.879700                 0.550337
#
#     val_loss  val_mean_absolute_percentage_error  val_root_mean_squared_error
# 0   0.974367                           33.160057                     0.987100
# 1   0.442035                           27.042076                     0.664857
# 2   0.408004                           25.815166                     0.638752
# 3   0.398241                           25.744537                     0.631063
# 4   0.390222                           26.063196                     0.624678
# ..       ...                                 ...                          ...
# 95  0.314110                           22.650492                     0.560455
# 96  0.317555                           23.357832                     0.563520
# 97  0.311390                           21.857317                     0.558023
# 98  0.320795                           23.299702                     0.566388
# 99  0.315722                           22.342466                     0.561891
#
# [100 rows x 6 columns]

# %%
# Evaluar el modelo en el conjunto de entrenamiento


#Evalúa el rendimiento del modelo en los conjuntos de entrenamiento, validación y prueba utilizando el método evaluate().
#Este código crea, entrena, evalúa y visualiza el rendimiento de una red neuronal para predecir los precios de las viviendas en California.

loss, RMSE, MAPE = model.evaluate(X_train, y_train)
print("Evaluar el modelo en el conjunto de entrenamiento")
print("loss train:", loss)
print("root_mean_squared_error train:", RMSE)
print("mean_absolute_percentage_error train:", MAPE)

# Evaluar el modelo en el conjunto de validación
loss, RMSE, MAPE = model.evaluate(X_valid, y_valid)
print("Evaluar el modelo en el conjunto de validación")
print("loss valid:", loss)
print("root_mean_squared_error valid:", RMSE)
print("mean_absolute_percentage_error valid:", MAPE)

# Evaluar el modelo en el conjunto de prueba
loss, RMSE, MAPE = model.evaluate(X_test, y_test)
print("Evaluar el modelo en el conjunto de prueba")
print("loss test:", loss)
print("root_mean_squared_error test:", RMSE)
print("mean_absolute_percentage_error test:", MAPE)
# Out:
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.3001 - mean_absolute_percentage_error: 21.6213 - root_mean_squared_error: 0.5477
# Evaluar el modelo en el conjunto de entrenamiento
# loss train: 0.30333900451660156
# root_mean_squared_error train: 0.5507621765136719
# mean_absolute_percentage_error train: 21.822172164916992
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - loss: 0.3325 - mean_absolute_percentage_error: 22.4331 - root_mean_squared_error: 0.5755
# Evaluar el modelo en el conjunto de validación
# loss valid: 0.31572169065475464
# root_mean_squared_error valid: 0.5618911981582642
# mean_absolute_percentage_error valid: 22.342466354370117
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.2994 - mean_absolute_percentage_error: 21.8006 - root_mean_squared_error: 0.5468
# Evaluar el modelo en el conjunto de prueba
# loss test: 0.3114457130432129
# root_mean_squared_error test: 0.5580732226371765
# mean_absolute_percentage_error test: 22.28622817993164

# %% [markdown]
#  1. ¿Qué función de activación se utiliza en la capa oculta de la red neuronal y por qué se elige esa
# función?
# ChatGPT Plus
# ChatGPT
# En el modelo que has proporcionado, la capa oculta utiliza la función de activación ReLU ('relu'), que es la abreviatura de Rectified Linear Unit.
#
# Razones para elegir ReLU:
# Simplicidad y eficiencia computacional:
#
# ReLU es una función muy simple y eficiente desde el punto de vista computacional porque solo necesita comparar el valor de entrada con cero y decidir si devolverlo o no. Esto permite un entrenamiento más rápido y eficaz, especialmente en redes neuronales profundas.
# Resolución del problema de desvanecimiento del gradiente:
#
# A diferencia de funciones de activación como la sigmoide o la tangente hiperbólica (tanh), ReLU no sufre del problema del desvanecimiento del gradiente, donde los gradientes se vuelven extremadamente pequeños, dificultando la actualización de los pesos en las capas anteriores. ReLU mantiene un gradiente constante para valores positivos, lo que ayuda a evitar este problema.
# Esparsidad inducida:
#
# ReLU introduce esparsidad en la activación de las neuronas, es decir, para una entrada dada, muchas neuronas pueden estar inactivas (activación igual a 0). Esto puede ayudar a que la red sea más eficiente y a capturar patrones más complejos.
# Mejor convergencia:
#
# En general, los modelos entrenados con ReLU tienden a converger más rápidamente que los modelos entrenados con funciones de activación como sigmoide o tanh

# %% [markdown]
# 2. ¿Qué función de pérdida se utiliza para compilar el modelo y qué métricas se utilizan para
# evaluar su rendimiento?
#
# ChatGPT Plus
# ChatGPT
# La función de pérdida utilizada para compilar el modelo es mean_squared_error (MSE), que es común en problemas de regresión. Las métricas utilizadas para evaluar su rendimiento son root_mean_squared_error (RMSE) y mean_absolute_percentage_error (MAPE).
